# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("case_time_series (2).csv")
df.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
df.head(5)
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered
# 0   30 January                 1                1                0  \
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
df.isnull().sum()
# Out:
# Date               0
# Daily Confirmed    0
# Total Confirmed    0
# Daily Recovered    0
# Total Recovered    0
# Daily Deceased     0
# Total Deceased     0
# dtype: int64

# %%
df1=pd.read_csv("case_time_series (2).csv")
df1.head(5)
# Out:
#            Date  Daily Confirmed  Total Confirmed  Daily Recovered
# 0   30 January                 1                1                0  \
# 1   31 January                 0                1                0
# 2  01 February                 0                1                0
# 3  02 February                 1                2                0
# 4  03 February                 1                3                0
#
#    Total Recovered  Daily Deceased  Total Deceased
# 0                0               0               0
# 1                0               0               0
# 2                0               0               0
# 3                0               0               0
# 4                0               0               0

# %%
df1.isnull().sum()
# Out:
# Date               0
# Daily Confirmed    0
# Total Confirmed    0
# Daily Recovered    0
# Total Recovered    0
# Daily Deceased     0
# Total Deceased     0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Date', 'Daily Confirmed', 'Total Confirmed', 'Daily Recovered',
#        'Total Recovered', 'Daily Deceased', 'Total Deceased'],
#       dtype='object')

# %%
y=df1.iloc[61:,1].values #comform case
r=df1.iloc[61:,3].values # recovery
d=df1.iloc[61:,4].values # decrease case

# %%
x=df1.iloc[61:,0]
# Out:
# 61     31 March
# 62     01 April
# 63     02 April
# 64     03 April
# 65     04 April
# 66     05 April
# 67     06 April
# 68     07 April
# 69     08 April
# 70     09 April
# 71     10 April
# 72     11 April
# 73     12 April
# 74     13 April
# 75     14 April
# 76     15 April
# 77     16 April
# 78     17 April
# 79     18 April
# 80     19 April
# 81     20 April
# 82     21 April
# 83     22 April
# 84     23 April
# 85     24 April
# 86     25 April
# 87     26 April
# 88     27 April
# 89     28 April
# 90     29 April
# 91     30 April
# 92       01 May
# 93       02 May
# 94       03 May
# 95       04 May
# 96       05 May
# 97       06 May
# 98       07 May
# 99       08 May
# 100      09 May
# 101      10 May
# 102      11 May
# 103      12 May
# 104      13 May
# Name: Date, dtype: object

# %%
plt.plot(x,y)
plt.show()

# %%
y=df1.iloc[61:,1].values
r=df1.iloc[61:,3].values # recovery
d=df1.iloc[61:,5].values # decrease case
x=df1.iloc[61:,0]
ax.plot(X,Y,
        color='#1F77B4',
        marker='o',
        linewidth=4,
        markersize=15,
        markeredgecolor='#035E9B')

plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       3 d=df1.iloc[61:,5].values # decrease case
#       4 x=df1.iloc[61:,0]
# ----> 5 ax.plot(X,Y,
#       6         color='#1F77B4',
#       7         marker='o',
#       8         linewidth=4,
#       9         markersize=15,
#      10         markeredgecolor='#035E9B')
#      12 plt.plot(x,y)
#      13 plt.show()
#
# NameError: name 'X' is not defined

# %%
# Aesthetics
plt.plot(x,y)
plt.figure(figsize=(25,8))# 25 is widht and 6 is height
ax = plt.axes()
ax.plot(X,Y,
        color='#1F77B4',
        marker='o',
        linewidth=4,
        markersize=15,
        markeredgecolor='#035E9B')

ax.grid(linewidth=0.4, color='#8f8f8f') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 5
#       3 plt.figure(figsize=(25,8))# 25 is widht and 6 is height
#       4 ax = plt.axes()
# ----> 5 ax.plot(X,Y,
#       6         color='#1F77B4',
#       7         marker='o',
#       8         linewidth=4,
#       9         markersize=15,
#      10         markeredgecolor='#035E9B')
#      12 ax.grid(linewidth=0.4, color='#8f8f8f')
#      13 plt.show()
#
# NameError: name 'X' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
data = pd.read_csv('case_time_series (2).csv')
 
Y = data.iloc[61:,1].values
R = data.iloc[61:,3].values
D = data.iloc[61:,5].values
X = data.iloc[61:,0]
 
plt.figure(figsize=(25,8))
 
ax = plt.axes()
ax.grid(linewidth=0.4, color='#8f8f8f')
 
ax.set_facecolor("black")
ax.set_xlabel('\nDate',size=25,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',
              size=25,color='#4bb4f2')
# plt.xticks(rotation='vertical',size='20',color='white')
# plt.yticks(size=20,color='white')
# plt.tick_params(size=20,color='white')
 
ax.plot(X,Y,
        color='#1F77B4',
        marker='o',
        linewidth=4,
        markersize=15,
        markeredgecolor='#035E9B')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('case_time_series (2).csv')

Y = data.iloc[61:,1].values
R = data.iloc[61:,3].values
D = data.iloc[61:,5].values
X = data.iloc[61:,0]

plt.figure(figsize=(25,8))

ax = plt.axes()
ax.grid(linewidth=0.4, color='#8f8f8f')

ax.set_facecolor("black")
ax.set_xlabel('\nDate',size=25,color='#4bb4f2')
ax.set_ylabel('Number of Confirmed Cases\n',
			size=25,color='#4bb4f2')

plt.xticks(rotation='vertical',size='20',color='white')
plt.yticks(size=20,color='white')
plt.tick_params(size=20,color='white')

for i,j in zip(X,Y):
	ax.annotate(str(j),xy=(i,j+100),color='white',size='13')
	
ax.annotate('Second Lockdown 15th April',
			xy=(15.2, 860),
			xytext=(19.9,500),
			color='white',
			size='25',
			arrowprops=dict(color='white',
							linewidth=0.025))

plt.title("COVID-19 IN : Daily Confirmed\n",
		size=50,color='#28a9ff')

ax.plot(X,Y,
		color='#1F77B4',
		marker='o',
		linewidth=4,
		markersize=15,
		markeredgecolor='#035E9B')
